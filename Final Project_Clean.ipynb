# %%
import pandas as pd
import numpy as np
import time
import random
import sqlite3
import copy
from plotnine import *
import matplotlib.pyplot as plt
import plotly.figure_factory as ff

# %%
url = "https://github.com/nytimes/covid-19-data/blob/master/prisons/facilities.csv"

#use pandas to read in tables from webpage
prison_data = pd.read_html(url)

# %%
#convert list to df
prison_df = pd.concat(prison_data, ignore_index = True)

# %%
prison_df.head()
# Out:
#    Unnamed: 0    nyt_id                                      facility_name  \
# 0         NaN  F3EFE858                      Alex City Work Release prison
# 1         NaN  5B910220      Alabama Therapeutic Education Facility prison
# 2         NaN  02FB1675                         Bibb Correctional Facility
# 3         NaN  6378F6C4  Birmingham Women's Community Based Facility an...
# 4         NaN  EAABF900                      Bullock Correctional Facility
#
#                  facility_type facility_city facility_county  \
# 0    Low-security work release     Alex City           Coosa
# 1  State rehabilitation center    Columbiana          Shelby
# 2                 State prison         Brent            Bibb
# 3                 State prison    Birmingham       Jefferson
# 4                 State prison      Bessemer         Bullock
#
#    facility_county_fips facility_state  facility_lng  facility_lat  \
# 0                  1037        Alabama    -86.009015     32.904507
# 1                  1117        Alabama    -86.624067     33.180755
# 2                  1007        Alabama    -87.162781     32.920754
# 3                  1073        Alabama    -86.808344     33.531101
# 4                  1011        Alabama    -85.673927     32.147144
#
#    latest_inmate_population  max_inmate_population_2020  total_inmate_cases  \
# 0                     188.0                         NaN                  77
# 1                     272.0                         NaN                  11
# 2                    1725.0                      1825.0                 164
# 3                     192.0                         NaN                  17
# 4                    1477.0                      1577.0                 162
#
#    total_inmate_deaths  total_officer_cases  total_officer_deaths note
# 0                    0                   17                   0.0  NaN
# 1                    1                    2                   0.0  NaN
# 2                    3                   61                   0.0  NaN
# 3                    0                   28                   0.0  NaN
# 4                    5                   80                   1.0  NaN

# %%
prison_df = prison_df.dropna(subset=['facility_county_fips', 'latest_inmate_population'])
#prison_df = prison_df.loc[prison_df.facility_type == "State prison"].reset_index()
prison_df = prison_df.loc[(prison_df.facility_type == "State prison") | (prison_df.facility_type == "Federal prison")].reset_index()

# %%
prison_df['max_inmate_population_2020'] = prison_df.max_inmate_population_2020.fillna(prison_df.latest_inmate_population)

# %%
prison_df_county = prison_df.groupby(['facility_county_fips', 'facility_county', 'facility_state'])[['max_inmate_population_2020', 'total_inmate_cases', 'total_inmate_deaths']].sum().reset_index()

# %%
prison_df_county
# Out:
#      facility_county_fips facility_county facility_state  \
# 0                    1003         Baldwin        Alabama
# 1                    1005         Barbour        Alabama
# 2                    1007            Bibb        Alabama
# 3                    1011         Bullock        Alabama
# 4                    1051          Elmore        Alabama
# ..                    ...             ...            ...
# 755                 56013         Fremont        Wyoming
# 756                 56015          Goshen        Wyoming
# 757                 56027        Niobrara        Wyoming
# 758                 56045          Weston        Wyoming
# 759                 72061        Guaynabo    Puerto Rico
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 755                       205.0                 203                    0
# 756                       583.0                  71                    0
# 757                       281.0                   3                    0
# 758                       213.0                 182                    0
# 759                      1249.0                  52                    0
#
# [760 rows x 6 columns]

# %%
county_covid_data = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

# %%
county_covid_df = county_covid_data.loc[county_covid_data.date == "2021-03-31"]

# %%
county_covid_df['fips'] = np.where((county_covid_df.county == 'New York City'),36061,county_covid_df.fips)

# %%
county_covid_df
# Out:
#                date      county    state     fips  cases  deaths
# 1173623  2021-03-31     Autauga  Alabama   1001.0   6589    99.0
# 1173624  2021-03-31     Baldwin  Alabama   1003.0  20505   301.0
# 1173625  2021-03-31     Barbour  Alabama   1005.0   2227    55.0
# 1173626  2021-03-31        Bibb  Alabama   1007.0   2542    58.0
# 1173627  2021-03-31      Blount  Alabama   1009.0   6444   131.0
# ...             ...         ...      ...      ...    ...     ...
# 1176865  2021-03-31  Sweetwater  Wyoming  56037.0   4022    37.0
# 1176866  2021-03-31       Teton  Wyoming  56039.0   3609     9.0
# 1176867  2021-03-31       Uinta  Wyoming  56041.0   2128    12.0
# 1176868  2021-03-31    Washakie  Wyoming  56043.0    890    26.0
# 1176869  2021-03-31      Weston  Wyoming  56045.0    633     5.0
#
# [3247 rows x 6 columns]

# %%
final_county = prison_df_county.merge(county_covid_df, left_on='facility_county_fips', right_on='fips', how='left')

# %%
final_county
# Out:
#      facility_county_fips facility_county facility_state  \
# 0                    1003         Baldwin        Alabama
# 1                    1005         Barbour        Alabama
# 2                    1007            Bibb        Alabama
# 3                    1011         Bullock        Alabama
# 4                    1051          Elmore        Alabama
# ..                    ...             ...            ...
# 755                 56013         Fremont        Wyoming
# 756                 56015          Goshen        Wyoming
# 757                 56027        Niobrara        Wyoming
# 758                 56045          Weston        Wyoming
# 759                 72061        Guaynabo    Puerto Rico
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 755                       205.0                 203                    0
# 756                       583.0                  71                    0
# 757                       281.0                   3                    0
# 758                       213.0                 182                    0
# 759                      1249.0                  52                    0
#
#            date    county        state     fips    cases  deaths
# 0    2021-03-31   Baldwin      Alabama   1003.0  20505.0   301.0
# 1    2021-03-31   Barbour      Alabama   1005.0   2227.0    55.0
# 2    2021-03-31      Bibb      Alabama   1007.0   2542.0    58.0
# 3    2021-03-31   Bullock      Alabama   1011.0   1207.0    40.0
# 4    2021-03-31    Elmore      Alabama   1051.0   9953.0   202.0
# ..          ...       ...          ...      ...      ...     ...
# 755  2021-03-31   Fremont      Wyoming  56013.0   5070.0    82.0
# 756  2021-03-31    Goshen      Wyoming  56015.0   1169.0    23.0
# 757  2021-03-31  Niobrara      Wyoming  56027.0    150.0     2.0
# 758  2021-03-31    Weston      Wyoming  56045.0    633.0     5.0
# 759  2021-03-31  Guaynabo  Puerto Rico  72061.0   4526.0     NaN
#
# [760 rows x 12 columns]

# %%
final_county = final_county.loc[final_county.facility_state != "Puerto Rico"].reset_index()

# %%
#Read in demographic data

population="/Users/anandigupta/Downloads/PopulationEstimates.csv"
populationdat = (pd.read_csv(population))

unemployment="/Users/anandigupta/Downloads/Unemployment.csv"
unemploymentdat = (pd.read_csv(unemployment))

poverty="/Users/anandigupta/Downloads/PovertyEstimates.csv"
povertydat=(pd.read_csv(poverty))

education="/Users/anandigupta/Downloads/Education.csv"
eddat=(pd.read_csv(education))

insurance="/Users/anandigupta/Downloads/SAHIE_13DEC21_14_29_28_65.csv"
insdat=(pd.read_csv(insurance))

race = "/Users/anandigupta/Downloads/cc-est2019-alldata.csv"
racedat=(pd.read_csv(race))

county_vote = pd.read_csv("/Users/anandigupta/Downloads/countypres_2000-2020.tab",sep='\t',header=(0))

incarceration = "/Users/anandigupta/Downloads/census_incarceration_TMP.csv"
incarcdat=(pd.read_csv(incarceration))

# %%
populationdat
populationdat = populationdat[['FIPStxt', 'Population 2020']]
populationdat['Population 2020'] = populationdat['Population 2020'].str.replace(',', '')

# %%
populationdat= populationdat.dropna(subset = ['Population 2020'])
populationdat['Population 2020'] = populationdat['Population 2020'].astype('int64')

# %%
populationdat.head()
# Out:
#    FIPStxt  Population 2020
# 0        0        331449281
# 1     1000          5024279
# 2     1001            58805
# 3     1003           231767
# 4     1005            25223

# %%
unemploymentdat.head()
unemploymentdat = unemploymentdat[['FIPS_Code', 'Unemployment_rate_2019', 'Unemployment_rate_2020', 'Median_Household_Income_2019']]
unemploymentdat['Median_Household_Income_2019'] = unemploymentdat['Median_Household_Income_2019'].str.replace(',', '')
unemploymentdat['Median_Household_Income_2019'] = unemploymentdat['Median_Household_Income_2019'].astype('float64')

# %%
unemploymentdat.head()
# Out:
#    FIPS_Code  Unemployment_rate_2019  Unemployment_rate_2020  \
# 0          0                     3.7                     8.1
# 1       1000                     3.0                     5.9
# 2       1001                     2.7                     4.9
# 3       1003                     2.8                     5.6
# 4       1005                     3.8                     7.0
#
#    Median_Household_Income_2019
# 0                       65712.0
# 1                       51771.0
# 2                       58233.0
# 3                       59871.0
# 4                       35972.0

# %%
povertydat = povertydat[['FIPStxt', 'PCTPOVALL_2019']]
povertydat.head()
# Out:
#    FIPStxt  PCTPOVALL_2019
# 0        0            12.3
# 1     1000            15.6
# 2     1001            12.1
# 3     1003            10.1
# 4     1005            27.1

# %%
type(populationdat.FIPStxt[0])
# Out:
# numpy.int64

# %%
eddat = eddat[['FIPS Code', 'Percent of adults with less than a high school diploma, 2015-19', 'Percent of adults with a high school diploma only, 2015-19', "Percent of adults with a bachelor's degree or higher, 2015-19"]]
eddat.head()
# Out:
#    FIPS Code  Percent of adults with less than a high school diploma, 2015-19  \
# 0          0                                               12.0
# 1       1000                                               13.8
# 2       1001                                               11.5
# 3       1003                                                9.2
# 4       1005                                               26.8
#
#    Percent of adults with a high school diploma only, 2015-19  \
# 0                                               27.0
# 1                                               30.8
# 2                                               33.6
# 3                                               27.7
# 4                                               35.6
#
#    Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                               32.1
# 1                                               25.5
# 2                                               26.6
# 3                                               31.9
# 4                                               11.6

# %%
type(eddat['FIPS Code'][0])
# Out:
# numpy.int64

# %%
insdat = insdat[['ID','Uninsured: %']]
insdat.head()
# Out:
#      ID  Uninsured: %
# 0  1000          11.6
# 1  1001           9.4
# 2  1003          10.9
# 3  1005          13.0
# 4  1007          11.0

# %%
type(insdat['ID'][0])
# Out:
# numpy.int64

# %%
racedat = racedat.loc[racedat.AGEGRP == 0].reset_index()
racedat = racedat.loc[racedat.YEAR == 12].reset_index()
racedat.head()
# Out:
#    level_0  index  SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  \
# 0       11    209      50      1       1  Alabama  Autauga County    12
# 1       23    437      50      1       3  Alabama  Baldwin County    12
# 2       35    665      50      1       5  Alabama  Barbour County    12
# 3       47    893      50      1       7  Alabama     Bibb County    12
# 4       59   1121      50      1       9  Alabama   Blount County    12
#
#    AGEGRP  TOT_POP  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0       0    55869  ...        778          687         89           93
# 1       0   223234  ...       5144         4646        268          281
# 2       0    24686  ...        509          408         63           50
# 3       0    22394  ...        291          253         32           19
# 4       0    57826  ...       2794         2516         76           58
#
#    HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE
# 0         40           27         15           19         16           11
# 1        264          197         69           65         55           35
# 2         61           26          1            0         14            8
# 3          6           15          5            1         17            3
# 4         67           66         18           21         34           21
#
# [5 rows x 82 columns]

# %%
racedat['COUNTY'] = racedat['COUNTY'].astype(str).str.zfill(3)
racedat['STATE'] = racedat['STATE'].astype(str).str.zfill(2)
racedat["FIPS"] =racedat["STATE"] + racedat["COUNTY"]

# %%
racedat["FIPS"] =racedat["FIPS"].astype('int64')

# %%
racedat.head()
# Out:
#    level_0  index  SUMLEV STATE COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  \
# 0       11    209      50    01    001  Alabama  Autauga County    12       0
# 1       23    437      50    01    003  Alabama  Baldwin County    12       0
# 2       35    665      50    01    005  Alabama  Barbour County    12       0
# 3       47    893      50    01    007  Alabama     Bibb County    12       0
# 4       59   1121      50    01    009  Alabama   Blount County    12       0
#
#    TOT_POP  ...  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  \
# 0    55869  ...          687         89           93         40           27
# 1   223234  ...         4646        268          281        264          197
# 2    24686  ...          408         63           50         61           26
# 3    22394  ...          253         32           19          6           15
# 4    57826  ...         2516         76           58         67           66
#
#    HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE  FIPS
# 0         15           19         16           11  1001
# 1         69           65         55           35  1003
# 2          1            0         14            8  1005
# 3          5            1         17            3  1007
# 4         18           21         34           21  1009
#
# [5 rows x 83 columns]

# %%
racedat['pct_white'] = (racedat['WA_MALE'] +  racedat['WA_FEMALE'])/ racedat['TOT_POP']
racedat = racedat[['FIPS', 'pct_white']]

# %%
county_vote.head()
county_vote = county_vote.loc[county_vote['candidate'] == "DONALD TRUMP"].reset_index()
county_vote = county_vote.loc[county_vote['year'] == 2016].reset_index()
county_vote.head()
# Out:
#    level_0  index  year    state state_po county_name  county_fips     office  \
# 0        0  40518  2016  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 1        1  40521  2016  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 2        2  40524  2016  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 3        3  40527  2016  ALABAMA       AL        BIBB       1007.0  PRESIDENT
# 4        4  40530  2016  ALABAMA       AL      BLOUNT       1009.0  PRESIDENT
#
#       candidate       party  candidatevotes  totalvotes   version   mode
# 0  DONALD TRUMP  REPUBLICAN         18172.0     24973.0  20191203  TOTAL
# 1  DONALD TRUMP  REPUBLICAN         72883.0     95215.0  20191203  TOTAL
# 2  DONALD TRUMP  REPUBLICAN          5454.0     10469.0  20191203  TOTAL
# 3  DONALD TRUMP  REPUBLICAN          6738.0      8819.0  20191203  TOTAL
# 4  DONALD TRUMP  REPUBLICAN         22859.0     25588.0  20191203  TOTAL

# %%
final_county['fips'].unique
# Out:
# <bound method Series.unique of 0       1003.0
# 1       1005.0
# 2       1007.0
# 3       1011.0
# 4       1051.0
#         ...
# 754    56007.0
# 755    56013.0
# 756    56015.0
# 757    56027.0
# 758    56045.0
# Name: fips, Length: 759, dtype: float64>

# %%
county_vote['trump_vote_share'] = county_vote['candidatevotes'] / county_vote['totalvotes']

# %%
county_vote = county_vote[['county_fips', 'trump_vote_share']]
county_vote
# Out:
#       county_fips  trump_vote_share
# 0          1001.0          0.727666
# 1          1003.0          0.765457
# 2          1005.0          0.520967
# 3          1007.0          0.764032
# 4          1009.0          0.893348
# ...           ...               ...
# 3153       2037.0          0.382853
# 3154       2038.0          0.224338
# 3155       2039.0          0.249158
# 3156       2040.0          0.298698
# 3157       2099.0          0.007911
#
# [3158 rows x 2 columns]

# %%
incarcdat.head()

incarcdat['incarc_rate'] = incarcdat['incarcerated_20']/incarcdat['total_population_20']
incarcdat = incarcdat[['FIPS', 'incarc_rate']]

# %%
incarcdat.head()
# Out:
#     FIPS  incarc_rate
# 0  25001     0.000930
# 1  25003     0.001457
# 2  25005     0.001528
# 3  25007     0.000728
# 4  25009     0.002615

# %%
url = "https://www.prisonpolicy.org/blog/2020/12/21/overcrowding/"

prison_capacity = "/Users/anandigupta/Downloads/Capacity.csv"
prison_capacity_dat=(pd.read_csv(prison_capacity))

# %%
prison_capacity_dat
# Out:
#      Prison system  Capacity_max  Capacity_min  As of this date:  Unnamed: 4  \
# 0          Alabama          1.53          0.86        Sept. 2020         NaN
# 1           Alaska          0.85          0.82       May 1, 2020         NaN
# 2          Arizona          0.98          0.85      Dec. 2, 2020         NaN
# 3         Arkansas          1.03          0.99        Sept. 2020         NaN
# 4       California          1.10          0.78      Dec. 2, 2020         NaN
# 5         Colorado          1.17          1.05  End of Nov. 2020         NaN
# 6         Delaware          1.25          0.91       May 1, 2020         NaN
# 7          Federal          1.03          1.03      Dec. 3, 2020         NaN
# 8          Florida          1.06          1.06       May 1, 2020         NaN
# 9          Georgia          0.87          0.75      Dec. 4, 2020         NaN
# 10          Hawaii          1.20          1.19     Nov. 30, 2020         NaN
# 11           Idaho          1.18          1.18       May 1, 2020         NaN
# 12        Illinois          0.69          0.64    Sept. 30, 2020         NaN
# 13         Indiana          0.83          0.83      Nov. 1, 2020         NaN
# 14            Iowa          1.05          1.05      Dec. 4, 2020         NaN
# 15          Kansas          0.88          0.85      Dec. 3, 2020         NaN
# 16        Kentucky          0.80          0.80      Dec. 4, 2020         NaN
# 17       Louisiana          0.92          0.84      July 1, 2020         NaN
# 18           Maine          0.73          0.49     Nov. 30, 2020         NaN
# 19        Maryland          0.91          0.91     Dec. 31, 2019         NaN
# 20   Massachusetts          0.93          0.69     Nov. 30, 2020         NaN
# 21        Michigan          0.94          0.92       May 1, 2020         NaN
# 22       Minnesota          0.78          0.78     Nov. 30, 2020         NaN
# 23     Mississippi          1.10          1.10     Nov. 30, 2020         NaN
# 24        Missouri          0.85          0.83       May 1, 2020         NaN
# 25         Montana          2.14          1.21      Dec. 3, 2020         NaN
# 26        Nebraska          1.58          1.17    Jan‑March 2020         NaN
# 27          Nevada          1.17          0.80     Nov. 29, 2020         NaN
# 28   New Hampshire          1.17          0.77      Nov. 1, 2020         NaN
# 29      New Jersey          1.10          0.80       May 1, 2020         NaN
# 30      New Mexico          1.25          0.90     Dec. 31, 2019         NaN
# 31        New York          0.71          0.70      Dec. 1, 2020         NaN
# 32  North Carolina          0.84          0.78      Dec. 4, 2020         NaN
# 33    North Dakota          0.97          0.97      Dec. 4, 2020         NaN
# 34        Oklahoma          0.87          0.78     Nov. 30, 2020         NaN
# 35          Oregon          0.95          0.89      July 1, 2020         NaN
# 36    Pennsylvania          0.85          0.77      Dec. 4, 2020         NaN
# 37    Rhode Island          0.63          0.60       May 1, 2020         NaN
# 38  South Carolina          0.73          0.73      Dec. 4, 2020         NaN
# 39    South Dakota          0.75          0.75     Oct. 31, 2020         NaN
# 40       Tennessee          1.26          0.84         Nov. 2020         NaN
# 41           Texas          1.01          0.97       May 1, 2020         NaN
# 42            Utah          0.84          0.80     Sept. 4, 2020         NaN
# 43         Vermont          0.88          0.87      Dec. 4, 2020         NaN
# 44        Virginia          0.86          0.86         Oct. 2020         NaN
# 45      Washington          0.95          0.95        Sept. 2020         NaN
# 46   West Virginia          1.11          1.05       May 1, 2020         NaN
# 47       Wisconsin          1.21          0.89     Nov. 27, 2020         NaN
# 48         Wyoming          0.98          0.94    Sept. 30, 2020         NaN
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN

# %%
rural_urban = "/Users/anandigupta/Downloads/ruralurbancodes2013.csv"
rural_urban_codes=(pd.read_csv(rural_urban))
rural_urban_codes = rural_urban_codes.dropna(subset = ['FIPS'])
rural_urban_codes
# Out:
#          FIPS State        County_Name Population_2010  RUCC_2013  \
# 0      1001.0    AL     Autauga County          54,571        2.0
# 1      1003.0    AL     Baldwin County         182,265        3.0
# 2      1005.0    AL     Barbour County          27,457        6.0
# 3      1007.0    AL        Bibb County          22,915        1.0
# 4      1009.0    AL      Blount County          57,322        1.0
# ...       ...   ...                ...             ...        ...
# 3229  72151.0    PR  Yabucoa Municipio          37,941        1.0
# 3230  72153.0    PR    Yauco Municipio          42,043        2.0
# 3231  78010.0    VI   St. Croix Island          50,601        5.0
# 3232  78020.0    VI    St. John Island           4,170        7.0
# 3233  78030.0    VI  St. Thomas Island          51,634        5.0
#
#                                             Description
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# 2     Nonmetro - Urban population of 2,500 to 19,999...
# 3     Metro - Counties in metro areas of 1 million p...
# 4     Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3229  Metro - Counties in metro areas of 1 million p...
# 3230  Metro - Counties in metro areas of 250,000 to ...
# 3231  Nonmetro - Urban population of 20,000 or more,...
# 3232  Nonmetro - Urban population of 2,500 to 19,999...
# 3233  Nonmetro - Urban population of 20,000 or more,...
#
# [3234 rows x 6 columns]

# %%
populationdat['FIPStxt'].unique
# Out:
# <bound method Series.unique of 0           0
# 1        1000
# 2        1001
# 3        1003
# 4        1005
#         ...
# 3275    72145
# 3276    72147
# 3277    72149
# 3278    72151
# 3279    72153
# Name: FIPStxt, Length: 3274, dtype: int64>

# %%
final_county = final_county.merge(populationdat, left_on= 'facility_county_fips', right_on= 'FIPStxt', how='left').merge(unemploymentdat, left_on= 'facility_county_fips', right_on= 'FIPS_Code', how='left').merge(racedat, left_on= 'facility_county_fips', right_on= 'FIPS', how='left').merge(eddat, left_on= 'facility_county_fips', right_on= 'FIPS Code', how='left').merge(insdat, left_on= 'facility_county_fips', right_on= 'ID', how='left').merge(povertydat, left_on= 'facility_county_fips', right_on= 'FIPStxt', how='left').merge(county_vote, left_on= 'facility_county_fips', right_on= 'county_fips', how='left').merge(incarcdat, left_on= 'facility_county_fips', right_on= 'FIPS', how='left')

# %%
final_county
# Out:
#      index  facility_county_fips facility_county facility_state  \
# 0        0                  1003         Baldwin        Alabama
# 1        1                  1005         Barbour        Alabama
# 2        2                  1007            Bibb        Alabama
# 3        3                  1011         Bullock        Alabama
# 4        4                  1051          Elmore        Alabama
# ..     ...                   ...             ...            ...
# 754    754                 56007          Carbon        Wyoming
# 755    755                 56013         Fremont        Wyoming
# 756    756                 56015          Goshen        Wyoming
# 757    757                 56027        Niobrara        Wyoming
# 758    758                 56045          Weston        Wyoming
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 754                       826.0                 420                    1
# 755                       205.0                 203                    0
# 756                       583.0                  71                    0
# 757                       281.0                   3                    0
# 758                       213.0                 182                    0
#
#            date    county    state  ...  \
# 0    2021-03-31   Baldwin  Alabama  ...
# 1    2021-03-31   Barbour  Alabama  ...
# 2    2021-03-31      Bibb  Alabama  ...
# 3    2021-03-31   Bullock  Alabama  ...
# 4    2021-03-31    Elmore  Alabama  ...
# ..          ...       ...      ...  ...
# 754  2021-03-31    Carbon  Wyoming  ...
# 755  2021-03-31   Fremont  Wyoming  ...
# 756  2021-03-31    Goshen  Wyoming  ...
# 757  2021-03-31  Niobrara  Wyoming  ...
# 758  2021-03-31    Weston  Wyoming  ...
#
#      Percent of adults with a high school diploma only, 2015-19  \
# 0                                                 27.7
# 1                                                 35.6
# 2                                                 44.9
# 3                                                 40.3
# 4                                                 32.5
# ..                                                 ...
# 754                                               38.2
# 755                                               29.7
# 756                                               28.2
# 757                                               34.7
# 758                                               37.4
#
#      Percent of adults with a bachelor's degree or higher, 2015-19     ID  \
# 0                                                 31.9               1003
# 1                                                 11.6               1005
# 2                                                 10.4               1007
# 3                                                 12.1               1011
# 4                                                 25.1               1051
# ..                                                 ...                ...
# 754                                               20.6              56007
# 755                                               24.3              56013
# 756                                               25.9              56015
# 757                                               18.0              56027
# 758                                               20.0              56045
#
#      Uninsured: %  FIPStxt_y  PCTPOVALL_2019  county_fips  trump_vote_share  \
# 0            10.9       1003            10.1       1003.0          0.765457
# 1            13.0       1005            27.1       1005.0          0.520967
# 2            11.0       1007            20.3       1007.0          0.764032
# 3            11.1       1011            30.0       1011.0          0.242038
# 4             8.9       1051            11.4       1051.0          0.741653
# ..            ...        ...             ...          ...               ...
# 754          17.7      56007            11.7      56007.0          0.691716
# 755          22.3      56013            12.9      56013.0          0.655995
# 756          15.5      56015            13.0      56015.0          0.762250
# 757          19.1      56027            15.1      56027.0          0.849315
# 758          14.3      56045            10.5      56045.0          0.860182
#
#      FIPS_y  incarc_rate
# 0      1003     0.005303
# 1      1005     0.099790
# 2      1007     0.083255
# 3      1011     0.152554
# 4      1051     0.060084
# ..      ...          ...
# 754   56007     0.037009
# 755   56013     0.008640
# 756   56015     0.048088
# 757   56027     0.112282
# 758   56045     0.064639
#
# [759 rows x 33 columns]

# %%
final_county = final_county.dropna(subset = ['Population 2020', 'cases'])
#final_county['Population 2020'] =final_county['Population 2020'].astype('int64')
#final_county['cases'] = final_county['cases'].astype('int64')

# %%
final_county['inmate_cases_per_100'] = final_county['total_inmate_cases']/final_county['max_inmate_population_2020']*100
final_county['inmate_deaths_per_1000'] = final_county['total_inmate_deaths']/final_county['max_inmate_population_2020']*1000
final_county['cases_per_100'] = final_county['cases']/final_county['Population 2020']*100
final_county['deaths_per_1000'] = final_county['deaths']/final_county['Population 2020']*1000
final_county['cases_diff'] = final_county['inmate_cases_per_100']-final_county['cases_per_100']
final_county['deaths_diff'] = final_county['inmate_deaths_per_1000']-final_county['deaths_per_1000']

# %%
final_county
# Out:
#      index  facility_county_fips facility_county facility_state  \
# 0        0                  1003         Baldwin        Alabama
# 1        1                  1005         Barbour        Alabama
# 2        2                  1007            Bibb        Alabama
# 3        3                  1011         Bullock        Alabama
# 4        4                  1051          Elmore        Alabama
# ..     ...                   ...             ...            ...
# 754    754                 56007          Carbon        Wyoming
# 755    755                 56013         Fremont        Wyoming
# 756    756                 56015          Goshen        Wyoming
# 757    757                 56027        Niobrara        Wyoming
# 758    758                 56045          Weston        Wyoming
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 754                       826.0                 420                    1
# 755                       205.0                 203                    0
# 756                       583.0                  71                    0
# 757                       281.0                   3                    0
# 758                       213.0                 182                    0
#
#            date    county    state  ...  county_fips  trump_vote_share  \
# 0    2021-03-31   Baldwin  Alabama  ...       1003.0          0.765457
# 1    2021-03-31   Barbour  Alabama  ...       1005.0          0.520967
# 2    2021-03-31      Bibb  Alabama  ...       1007.0          0.764032
# 3    2021-03-31   Bullock  Alabama  ...       1011.0          0.242038
# 4    2021-03-31    Elmore  Alabama  ...       1051.0          0.741653
# ..          ...       ...      ...  ...          ...               ...
# 754  2021-03-31    Carbon  Wyoming  ...      56007.0          0.691716
# 755  2021-03-31   Fremont  Wyoming  ...      56013.0          0.655995
# 756  2021-03-31    Goshen  Wyoming  ...      56015.0          0.762250
# 757  2021-03-31  Niobrara  Wyoming  ...      56027.0          0.849315
# 758  2021-03-31    Weston  Wyoming  ...      56045.0          0.860182
#
#      FIPS_y  incarc_rate  inmate_cases_per_100  inmate_deaths_per_1000  \
# 0      1003     0.005303             82.812500                0.000000
# 1      1005     0.099790              6.180008                1.659063
# 2      1007     0.083255              8.986301                1.643836
# 3      1011     0.152554             10.272670                3.170577
# 4      1051     0.060084              7.646603                2.066649
# ..      ...          ...                   ...                     ...
# 754   56007     0.037009             50.847458                1.210654
# 755   56013     0.008640             99.024390                0.000000
# 756   56015     0.048088             12.178388                0.000000
# 757   56027     0.112282              1.067616                0.000000
# 758   56045     0.064639             85.446009                0.000000
#
#      cases_per_100  deaths_per_1000  cases_diff  deaths_diff
# 0         8.847247         1.298718   73.965253    -1.298718
# 1         8.829243         2.180549   -2.649235    -0.521487
# 2        11.402682         2.601714   -2.416381    -0.957878
# 3        11.653954         3.862122   -1.381284    -0.691545
# 4        11.313184         2.296055   -3.666581    -0.229405
# ..             ...              ...         ...          ...
# 754      10.428562         1.582170   40.418896    -0.371516
# 755      12.922465         2.090024   86.101925    -2.090024
# 756       9.353497         1.840294    2.824891    -1.840294
# 757       6.080259         0.810701   -5.012644    -0.810701
# 758       9.257093         0.731208   76.188917    -0.731208
#
# [757 rows x 39 columns]

# %%
#drop six instances with data errors (cases recorded in jails greater than number of inmates)
final_county = final_county.loc[final_county['inmate_cases_per_100'] < 100].reset_index()

# %%
final_county
# Out:
#      level_0  index  facility_county_fips facility_county facility_state  \
# 0          0      0                  1003         Baldwin        Alabama
# 1          1      1                  1005         Barbour        Alabama
# 2          2      2                  1007            Bibb        Alabama
# 3          3      3                  1011         Bullock        Alabama
# 4          4      4                  1051          Elmore        Alabama
# ..       ...    ...                   ...             ...            ...
# 746      754    754                 56007          Carbon        Wyoming
# 747      755    755                 56013         Fremont        Wyoming
# 748      756    756                 56015          Goshen        Wyoming
# 749      757    757                 56027        Niobrara        Wyoming
# 750      758    758                 56045          Weston        Wyoming
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 746                       826.0                 420                    1
# 747                       205.0                 203                    0
# 748                       583.0                  71                    0
# 749                       281.0                   3                    0
# 750                       213.0                 182                    0
#
#            date    county  ... county_fips  trump_vote_share  FIPS_y  \
# 0    2021-03-31   Baldwin  ...      1003.0          0.765457    1003
# 1    2021-03-31   Barbour  ...      1005.0          0.520967    1005
# 2    2021-03-31      Bibb  ...      1007.0          0.764032    1007
# 3    2021-03-31   Bullock  ...      1011.0          0.242038    1011
# 4    2021-03-31    Elmore  ...      1051.0          0.741653    1051
# ..          ...       ...  ...         ...               ...     ...
# 746  2021-03-31    Carbon  ...     56007.0          0.691716   56007
# 747  2021-03-31   Fremont  ...     56013.0          0.655995   56013
# 748  2021-03-31    Goshen  ...     56015.0          0.762250   56015
# 749  2021-03-31  Niobrara  ...     56027.0          0.849315   56027
# 750  2021-03-31    Weston  ...     56045.0          0.860182   56045
#
#      incarc_rate  inmate_cases_per_100  inmate_deaths_per_1000  cases_per_100  \
# 0       0.005303             82.812500                0.000000       8.847247
# 1       0.099790              6.180008                1.659063       8.829243
# 2       0.083255              8.986301                1.643836      11.402682
# 3       0.152554             10.272670                3.170577      11.653954
# 4       0.060084              7.646603                2.066649      11.313184
# ..           ...                   ...                     ...            ...
# 746     0.037009             50.847458                1.210654      10.428562
# 747     0.008640             99.024390                0.000000      12.922465
# 748     0.048088             12.178388                0.000000       9.353497
# 749     0.112282              1.067616                0.000000       6.080259
# 750     0.064639             85.446009                0.000000       9.257093
#
#      deaths_per_1000  cases_diff  deaths_diff
# 0           1.298718   73.965253    -1.298718
# 1           2.180549   -2.649235    -0.521487
# 2           2.601714   -2.416381    -0.957878
# 3           3.862122   -1.381284    -0.691545
# 4           2.296055   -3.666581    -0.229405
# ..               ...         ...          ...
# 746         1.582170   40.418896    -0.371516
# 747         2.090024   86.101925    -2.090024
# 748         1.840294    2.824891    -1.840294
# 749         0.810701   -5.012644    -0.810701
# 750         0.731208   76.188917    -0.731208
#
# [751 rows x 40 columns]

# %%
final_county = final_county.merge(prison_capacity_dat, left_on= 'facility_state', right_on= 'Prison system', how='left')
final_county
# Out:
#      level_0  index  facility_county_fips facility_county facility_state  \
# 0          0      0                  1003         Baldwin        Alabama
# 1          1      1                  1005         Barbour        Alabama
# 2          2      2                  1007            Bibb        Alabama
# 3          3      3                  1011         Bullock        Alabama
# 4          4      4                  1051          Elmore        Alabama
# ..       ...    ...                   ...             ...            ...
# 746      754    754                 56007          Carbon        Wyoming
# 747      755    755                 56013         Fremont        Wyoming
# 748      756    756                 56015          Goshen        Wyoming
# 749      757    757                 56027        Niobrara        Wyoming
# 750      758    758                 56045          Weston        Wyoming
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 746                       826.0                 420                    1
# 747                       205.0                 203                    0
# 748                       583.0                  71                    0
# 749                       281.0                   3                    0
# 750                       213.0                 182                    0
#
#            date    county  ... cases_per_100  deaths_per_1000  cases_diff  \
# 0    2021-03-31   Baldwin  ...      8.847247         1.298718   73.965253
# 1    2021-03-31   Barbour  ...      8.829243         2.180549   -2.649235
# 2    2021-03-31      Bibb  ...     11.402682         2.601714   -2.416381
# 3    2021-03-31   Bullock  ...     11.653954         3.862122   -1.381284
# 4    2021-03-31    Elmore  ...     11.313184         2.296055   -3.666581
# ..          ...       ...  ...           ...              ...         ...
# 746  2021-03-31    Carbon  ...     10.428562         1.582170   40.418896
# 747  2021-03-31   Fremont  ...     12.922465         2.090024   86.101925
# 748  2021-03-31    Goshen  ...      9.353497         1.840294    2.824891
# 749  2021-03-31  Niobrara  ...      6.080259         0.810701   -5.012644
# 750  2021-03-31    Weston  ...      9.257093         0.731208   76.188917
#
#      deaths_diff  Prison system  Capacity_max  Capacity_min  As of this date:  \
# 0      -1.298718        Alabama          1.53          0.86        Sept. 2020
# 1      -0.521487        Alabama          1.53          0.86        Sept. 2020
# 2      -0.957878        Alabama          1.53          0.86        Sept. 2020
# 3      -0.691545        Alabama          1.53          0.86        Sept. 2020
# 4      -0.229405        Alabama          1.53          0.86        Sept. 2020
# ..           ...            ...           ...           ...               ...
# 746    -0.371516        Wyoming          0.98          0.94    Sept. 30, 2020
# 747    -2.090024        Wyoming          0.98          0.94    Sept. 30, 2020
# 748    -1.840294        Wyoming          0.98          0.94    Sept. 30, 2020
# 749    -0.810701        Wyoming          0.98          0.94    Sept. 30, 2020
# 750    -0.731208        Wyoming          0.98          0.94    Sept. 30, 2020
#
#      Unnamed: 4  Unnamed: 5
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 746         NaN         NaN
# 747         NaN         NaN
# 748         NaN         NaN
# 749         NaN         NaN
# 750         NaN         NaN
#
# [751 rows x 46 columns]

# %%
final_county = final_county.merge(rural_urban_codes, left_on= 'facility_county_fips', right_on= 'FIPS', how='left')
final_county
# Out:
#      level_0  index  facility_county_fips facility_county facility_state  \
# 0          0      0                  1003         Baldwin        Alabama
# 1          1      1                  1005         Barbour        Alabama
# 2          2      2                  1007            Bibb        Alabama
# 3          3      3                  1011         Bullock        Alabama
# 4          4      4                  1051          Elmore        Alabama
# ..       ...    ...                   ...             ...            ...
# 746      754    754                 56007          Carbon        Wyoming
# 747      755    755                 56013         Fremont        Wyoming
# 748      756    756                 56015          Goshen        Wyoming
# 749      757    757                 56027        Niobrara        Wyoming
# 750      758    758                 56045          Weston        Wyoming
#
#      max_inmate_population_2020  total_inmate_cases  total_inmate_deaths  \
# 0                         128.0                 106                    0
# 1                        2411.0                 149                    4
# 2                        1825.0                 164                    3
# 3                        1577.0                 162                    5
# 4                        3871.0                 296                    8
# ..                          ...                 ...                  ...
# 746                       826.0                 420                    1
# 747                       205.0                 203                    0
# 748                       583.0                  71                    0
# 749                       281.0                   3                    0
# 750                       213.0                 182                    0
#
#            date    county  ... Capacity_min  As of this date:  Unnamed: 4  \
# 0    2021-03-31   Baldwin  ...         0.86        Sept. 2020         NaN
# 1    2021-03-31   Barbour  ...         0.86        Sept. 2020         NaN
# 2    2021-03-31      Bibb  ...         0.86        Sept. 2020         NaN
# 3    2021-03-31   Bullock  ...         0.86        Sept. 2020         NaN
# 4    2021-03-31    Elmore  ...         0.86        Sept. 2020         NaN
# ..          ...       ...  ...          ...               ...         ...
# 746  2021-03-31    Carbon  ...         0.94    Sept. 30, 2020         NaN
# 747  2021-03-31   Fremont  ...         0.94    Sept. 30, 2020         NaN
# 748  2021-03-31    Goshen  ...         0.94    Sept. 30, 2020         NaN
# 749  2021-03-31  Niobrara  ...         0.94    Sept. 30, 2020         NaN
# 750  2021-03-31    Weston  ...         0.94    Sept. 30, 2020         NaN
#
#      Unnamed: 5     FIPS  State      County_Name  Population_2010  RUCC_2013  \
# 0           NaN   1003.0     AL   Baldwin County          182,265        3.0
# 1           NaN   1005.0     AL   Barbour County           27,457        6.0
# 2           NaN   1007.0     AL      Bibb County           22,915        1.0
# 3           NaN   1011.0     AL   Bullock County           10,914        6.0
# 4           NaN   1051.0     AL    Elmore County           79,303        2.0
# ..          ...      ...    ...              ...              ...        ...
# 746         NaN  56007.0     WY    Carbon County           15,885        7.0
# 747         NaN  56013.0     WY   Fremont County           40,123        7.0
# 748         NaN  56015.0     WY    Goshen County           13,249        7.0
# 749         NaN  56027.0     WY  Niobrara County            2,484        9.0
# 750         NaN  56045.0     WY    Weston County            7,208        7.0
#
#                                            Description
# 0    Metro - Counties in metro areas of fewer than ...
# 1    Nonmetro - Urban population of 2,500 to 19,999...
# 2    Metro - Counties in metro areas of 1 million p...
# 3    Nonmetro - Urban population of 2,500 to 19,999...
# 4    Metro - Counties in metro areas of 250,000 to ...
# ..                                                 ...
# 746  Nonmetro - Urban population of 2,500 to 19,999...
# 747  Nonmetro - Urban population of 2,500 to 19,999...
# 748  Nonmetro - Urban population of 2,500 to 19,999...
# 749  Nonmetro - Completely rural or less than 2,500...
# 750  Nonmetro - Urban population of 2,500 to 19,999...
#
# [751 rows x 52 columns]

# %%
#y = final_county[final_county['cases'].isnull()]
#y = county_covid_data[county_covid_data['fips'].isnull()]

# %%
#y

# %%
#x = eddat.loc[eddat['FIPS Code'] == 36061].reset_index()

# %%
#x

# %%
#type(x['FIPS Code'][0])

# %%
#x = county_covid_df.loc[county_covid_df['county'] == "New York City"].reset_index()

# %%
#x

# %%
#county_covid_df['fips'] = np.where((county_covid_df.county == 'New York City'),36061,county_covid_df.fips)

# %%
#x

# %%
#populationdat.head()

# %%
#populationdat['Population 2020'] = populationdat['Population 2020'].str.replace(',', '')

# %%
#type(populationdat['Population 2020'][0])

# %%
import geopandas as gp

# %%
import mapclassify

# %%
countyshp=('/Users/anandigupta/Downloads/USA_Counties/USA_Counties.shp')
countyshp=gp.read_file(countyshp)

# %%
countyshp['FIPS'] = countyshp['FIPS'].astype('int64')

# %%
countymap = countyshp.merge(final_county, how='left', left_on="FIPS", right_on= "facility_county_fips")

# %%
countymap
# Out:
#        FID  OBJECTID       NAME   STATE_NAME STATE_FIPS CNTY_FIPS  FIPS_x  \
# 0        1         1    Autauga      Alabama         01       001    1001
# 1        2         2    Baldwin      Alabama         01       003    1003
# 2        3         3    Barbour      Alabama         01       005    1005
# 3        4         4       Bibb      Alabama         01       007    1007
# 4        5         5     Blount      Alabama         01       009    1009
# ...    ...       ...        ...          ...        ...       ...     ...
# 3215  3216      3216  Vega Baja  Puerto Rico         72       145   72145
# 3216  3217      3217    Vieques  Puerto Rico         72       147   72147
# 3217  3218      3218   Villalba  Puerto Rico         72       149   72149
# 3218  3219      3219    Yabucoa  Puerto Rico         72       151   72151
# 3219  3220      3220      Yauco  Puerto Rico         72       153   72153
#
#       POPULATION  POP_SQMI  POP2010  ...  Capacity_min  As of this date:  \
# 0          58224      96.4    54571  ...           NaN               NaN
# 1         227660     138.8   182265  ...          0.86        Sept. 2020
# 2          26326      29.1    27457  ...          0.86        Sept. 2020
# 3          23066      36.8    22915  ...          0.86        Sept. 2020
# 4          59970      92.2    57322  ...           NaN               NaN
# ...          ...       ...      ...  ...           ...               ...
# 3215           0       0.0        0  ...           NaN               NaN
# 3216           0       0.0        0  ...           NaN               NaN
# 3217           0       0.0        0  ...           NaN               NaN
# 3218           0       0.0        0  ...           NaN               NaN
# 3219           0       0.0        0  ...           NaN               NaN
#
#       Unnamed: 4  Unnamed: 5  FIPS_y  State     County_Name  Population_2010  \
# 0            NaN         NaN     NaN    NaN             NaN              NaN
# 1            NaN         NaN  1003.0     AL  Baldwin County          182,265
# 2            NaN         NaN  1005.0     AL  Barbour County           27,457
# 3            NaN         NaN  1007.0     AL     Bibb County           22,915
# 4            NaN         NaN     NaN    NaN             NaN              NaN
# ...          ...         ...     ...    ...             ...              ...
# 3215         NaN         NaN     NaN    NaN             NaN              NaN
# 3216         NaN         NaN     NaN    NaN             NaN              NaN
# 3217         NaN         NaN     NaN    NaN             NaN              NaN
# 3218         NaN         NaN     NaN    NaN             NaN              NaN
# 3219         NaN         NaN     NaN    NaN             NaN              NaN
#
#       RUCC_2013                                        Description
# 0           NaN                                                NaN
# 1           3.0  Metro - Counties in metro areas of fewer than ...
# 2           6.0  Nonmetro - Urban population of 2,500 to 19,999...
# 3           1.0  Metro - Counties in metro areas of 1 million p...
# 4           NaN                                                NaN
# ...         ...                                                ...
# 3215        NaN                                                NaN
# 3216        NaN                                                NaN
# 3217        NaN                                                NaN
# 3218        NaN                                                NaN
# 3219        NaN                                                NaN
#
# [3220 rows x 114 columns]

# %%
not_mainland = ['Alaska', 'Hawaii']
mainland_usa = countymap.query('STATE_NAME not in @not_mainland')
mainland_usa.sort_values("STATE_NAME")
missing_kwds = dict(color='grey', label='No Data')
fig, ax = plt.subplots(1, 1, figsize=[14,11])
plt.title("Difference in Cases per 100 Population in Jails and the General Population by County", x=.5, y=.95, fontname="DejaVu Sans"),
(mainland_usa.plot(column='cases_diff', cmap='Reds', scheme='quantiles', k=10, 
                  legend=True, ax=ax, legend_kwds={'loc': 'lower right'}, missing_kwds=missing_kwds))
# Out:
# <AxesSubplot:title={'center':'Difference in Cases per 100 Population in Jails and the General Population by County'}>

# %%
fig, ax = plt.subplots(1, 1, figsize=[14,11])
plt.title("Difference in Deaths per 1000 Population in Jails and the General Population by County", x=.5, y=.95, fontname="DejaVu Sans"),
(mainland_usa.plot(column='deaths_diff', cmap='Reds', scheme='quantiles', k=5, 
                  legend=True, ax=ax, legend_kwds={'loc': 'lower right'}, missing_kwds=missing_kwds))
# Out:
# <AxesSubplot:title={'center':'Difference in Deaths per 1000 Population in Jails and the General Population by County'}>

# %% [markdown]
# # Data modeling

# %%
# Data Management/Investigation
import pandas as pd
from pandas.api.types import CategoricalDtype # Ordering categories
import numpy as np
import missingno as miss

# Plotting libraries
from plotnine import *
import matplotlib.pyplot as plt

# For pre-processing data 
from sklearn import preprocessing as pp 
from sklearn.compose import ColumnTransformer 

# For splits and CV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold # Cross validation 
from sklearn.model_selection import cross_validate # Cross validation 
from sklearn.model_selection import GridSearchCV # Cross validation + param. tuning.

# Machine learning methods 
from sklearn.linear_model import LinearRegression as LM
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.tree import DecisionTreeRegressor as DT_reg
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.ensemble import BaggingRegressor as Bag
from sklearn import tree # For plotting the decision tree rules

# For evaluating our model's performance
import sklearn.metrics as m

# Pipeline to combine modeling elements
from sklearn.pipeline import Pipeline

# For model interpretation
from sklearn.inspection import (
    permutation_importance,
    partial_dependence, 
    PartialDependenceDisplay, 
    plot_partial_dependence
)

# Misc
import warnings
warnings.filterwarnings("ignore")

# %%
dat = final_county[['cases_diff', 'incarc_rate', 'pct_white', 'Unemployment_rate_2019','Unemployment_rate_2020', 'PCTPOVALL_2019', 'Median_Household_Income_2019', 'Uninsured: %', 'Percent of adults with less than a high school diploma, 2015-19', 'Percent of adults with a high school diploma only, 2015-19', "Percent of adults with a bachelor's degree or higher, 2015-19", 'trump_vote_share', 'Capacity_min', 'Capacity_max', 'RUCC_2013']]
#dat = final_county[['cases_diff', 'incarc_rate', 'pct_white', 'Unemployment_rate_2019', 'Unemployment_rate_2020', 'PCTPOVALL_2019', 'Median_Household_Income_2019', 'Uninsured: %', 'Percent of adults with less than a high school diploma, 2015-19', 'Percent of adults with a high school diploma only, 2015-19', "Percent of adults with a bachelor's degree or higher, 2015-19", 'trump_vote_share', 'RUCC_2013']]
dat.head()
# Out:
#    cases_diff  incarc_rate  pct_white  Unemployment_rate_2019  \
# 0   73.965253     0.005303   0.874410                     2.8
# 1   -2.649235     0.099790   0.491534                     3.8
# 2   -2.416381     0.083255   0.767661                     3.1
# 3   -1.381284     0.152554   0.266211                     3.7
# 4   -3.666581     0.060084   0.756825                     2.6
#
#    Unemployment_rate_2020  PCTPOVALL_2019  Median_Household_Income_2019  \
# 0                     5.6            10.1                       59871.0
# 1                     7.0            27.1                       35972.0
# 2                     6.6            20.3                       47918.0
# 3                     5.5            30.0                       31906.0
# 4                     4.9            11.4                       62310.0
#
#    Uninsured: %  \
# 0          10.9
# 1          13.0
# 2          11.0
# 3          11.1
# 4           8.9
#
#    Percent of adults with less than a high school diploma, 2015-19  \
# 0                                                9.2
# 1                                               26.8
# 2                                               20.9
# 3                                               25.3
# 4                                               13.4
#
#    Percent of adults with a high school diploma only, 2015-19  \
# 0                                               27.7
# 1                                               35.6
# 2                                               44.9
# 3                                               40.3
# 4                                               32.5
#
#    Percent of adults with a bachelor's degree or higher, 2015-19  \
# 0                                               31.9
# 1                                               11.6
# 2                                               10.4
# 3                                               12.1
# 4                                               25.1
#
#    trump_vote_share  Capacity_min  Capacity_max  RUCC_2013
# 0          0.765457          0.86          1.53        3.0
# 1          0.520967          0.86          1.53        6.0
# 2          0.764032          0.86          1.53        1.0
# 3          0.242038          0.86          1.53        6.0
# 4          0.741653          0.86          1.53        2.0

# %%
dat.shape
# Out:
# (751, 15)

# %%
dat.dtypes
# Out:
# cases_diff                                                         float64
# incarc_rate                                                        float64
# pct_white                                                          float64
# Unemployment_rate_2019                                             float64
# Unemployment_rate_2020                                             float64
# PCTPOVALL_2019                                                     float64
# Median_Household_Income_2019                                       float64
# Uninsured: %                                                       float64
# Percent of adults with less than a high school diploma, 2015-19    float64
# Percent of adults with a high school diploma only, 2015-19         float64
# Percent of adults with a bachelor's degree or higher, 2015-19      float64
# trump_vote_share                                                   float64
# Capacity_min                                                       float64
# Capacity_max                                                       float64
# RUCC_2013                                                          float64
# dtype: object

# %%
dat.isna().sum()

dat= dat.dropna()

# %%
#Split data into train and test

y = dat[['cases_diff']]
X = dat.drop(columns=['cases_diff'])
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size = .25,random_state=123)

# %%
print(train_X.shape[0]/dat.shape[0])
print(test_X.shape[0]/dat.shape[0])
# Out:
# 0.7487266553480475
# 0.25127334465195245

# %% [markdown]
# ## Explore the training data

# %%
#Explore the training data

#Check for missingness

miss.matrix(train_X) # No missing data
# Out:
# <AxesSubplot:>

# %%
train_X.isna().sum()
# Out:
# incarc_rate                                                        0
# pct_white                                                          0
# Unemployment_rate_2019                                             0
# Unemployment_rate_2020                                             0
# PCTPOVALL_2019                                                     0
# Median_Household_Income_2019                                       0
# Uninsured: %                                                       0
# Percent of adults with less than a high school diploma, 2015-19    0
# Percent of adults with a high school diploma only, 2015-19         0
# Percent of adults with a bachelor's degree or higher, 2015-19      0
# trump_vote_share                                                   0
# Capacity_min                                                       0
# Capacity_max                                                       0
# RUCC_2013                                                          0
# dtype: int64

# %%
#Explore the training data

# Plot the continuous Variables 
d = train_X.select_dtypes(include="float").melt()
(
    ggplot(d,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,3),
          subplots_adjust={'wspace':0.3, 'hspace': 0.5})
)
# Out:
# <ggplot: (8787196122612)>

# %% [markdown]
# As many variables are skewed, they will need to be logged

# %%
d = train_X.copy()
d['ln_pov'] =  np.log(d['PCTPOVALL_2019'])
d['ln_unemp'] =  np.log(d['Unemployment_rate_2019'])
d['ln_uninsured'] =  np.log(d['Uninsured: %'])

# Plot the continuous Variables 
d = d.filter(['ln_pov', 'ln_unemp', 'ln_uninsured']).melt()
(
    ggplot(d,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,3),
          subplots_adjust={'wspace':0.25})
)
# Out:
# <ggplot: (8787229377214)>

# %% [markdown]
# ## Pre-Processing Pipeline

# %%
#log skewed variables (add 1 as log of 0 is negative infinity)

dat['PCTPOVALL_2019'] =  np.log(dat['PCTPOVALL_2019']+ 1)
dat['Unemployment_rate_2019'] =  np.log(dat['Unemployment_rate_2019'] + 1)
dat['Uninsured: %'] =  np.log(dat['Uninsured: %'] + 1)
dat['incarc_rate'] =  np.log(dat['incarc_rate'] + 1)


#re-split using changed data

y = dat[['cases_diff']]
X = dat.drop(columns=['cases_diff'])

train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# %%
# from sklearn.impute import SimpleImputer 
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# train_X = imputer.fit_transform(train_X)
# test_X = imputer.fit_transform(test_X)

# %%
print(train_X.shape[0]/dat.shape[0])
print(test_X.shape[0]/dat.shape[0])
# Out:
# 0.7487266553480475
# 0.25127334465195245

# %%
# Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=123)

# %%
## Initialize Pipeline

#Note that we still want to scale values, but we want to do this in the pipeline since it utilizes information we'll only learn from the training data (i.e. min/max, mean, std, etc.)

pipe = Pipeline(steps=[('pre_process', pp.MinMaxScaler()),('model',None)])

# %%
## Select Models & Tuning Parameters

search_space = [
    
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[5,10,25,50]},
    
    # Decision Tree with the Max Depth Param
    {'model': [DT()],
     'model__max_depth':[2,3,4]},
    
    
    # Random forest with the N Estimators tuning param
    {'model' : [RF()],
    'model__max_depth':[2,3,4],
    'model__n_estimators':[500,1000,1500]}
    
]

# %%
## Run Models


search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_mean_squared_error',
                      n_jobs=4)



search.fit(train_X,train_y.cases_diff)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=123, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process', MinMaxScaler()),
#                                        ('model', None)]),
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsClassifier()],
#                           'model__n_neighbors': [5, 10, 25, 50]},
#                          {'model': [DecisionTreeClassifier()],
#                           'model__max_depth': [2, 3, 4]},
#                          {'model': [RandomForestClassifier()],
#                           'model__max_depth': [2, 3, 4],
#                           'model__n_estimators': [500, 1000, 1500]}],
#              scoring='neg_mean_squared_error')

# %%
search.best_score_
# Out:
# -497.3104264303076

# %%
search.best_params_
# Out:
# {'model': LinearRegression()}

# %%
# Predict() method will use the best model out of the scan
pred_y = search.predict(test_X)

# %%
m.mean_squared_error(test_y,pred_y)
# Out:
# 404.21902007800827

# %%
m.r2_score(test_y,pred_y)
# Out:
# 0.19758210168537438

# %%
train_X
# Out:
#      incarc_rate  pct_white  Unemployment_rate_2019  Unemployment_rate_2020  \
# 680     0.014115   0.622487                1.568616                     6.8
# 183     0.072502   0.441052                1.648659                     6.4
# 276     0.070995   0.496663                1.902108                     9.8
# 684     0.087097   0.602847                1.435085                     6.5
# 280     0.024688   0.963743                1.280934                     5.4
# ..           ...        ...                     ...                     ...
# 111     0.073273   0.594171                1.609438                     6.0
# 335     0.003008   0.250729                1.856298                     9.3
# 395     0.108637   0.855741                1.386294                     4.2
# 378     0.023765   0.944619                1.252763                     5.6
# 654     0.004317   0.871255                1.223775                     5.1
#
#      PCTPOVALL_2019  Median_Household_Income_2019  Uninsured: %  \
# 680        2.906901                       43128.0      2.564949
# 183        3.109061                       41674.0      2.809403
# 276        2.980619                       55198.0      2.272126
# 684        2.230014                       74518.0      2.151762
# 280        2.476538                       55910.0      2.525729
# ..              ...                           ...           ...
# 111        3.165475                       37919.0      2.873565
# 335        3.049273                       44773.0      2.785011
# 395        2.687847                       60086.0      2.433613
# 378        2.549445                       56677.0      2.128232
# 654        2.302585                       79941.0      2.517696
#
#      Percent of adults with less than a high school diploma, 2015-19  \
# 680                                               18.1
# 183                                               18.7
# 276                                               20.4
# 684                                                9.4
# 280                                                6.4
# ..                                                 ...
# 111                                               19.0
# 335                                               12.5
# 395                                               11.9
# 378                                                7.0
# 654                                                9.2
#
#      Percent of adults with a high school diploma only, 2015-19  \
# 680                                               31.8
# 183                                               44.7
# 276                                               41.3
# 684                                               33.8
# 280                                               32.9
# ..                                                 ...
# 111                                               39.7
# 335                                               25.0
# 395                                               41.5
# 378                                               34.2
# 654                                               22.6
#
#      Percent of adults with a bachelor's degree or higher, 2015-19  \
# 680                                               20.2
# 183                                               12.3
# 276                                               13.9
# 684                                               23.6
# 280                                               33.5
# ..                                                 ...
# 111                                               14.0
# 335                                               29.0
# 395                                               13.2
# 378                                               22.2
# 654                                               35.6
#
#      trump_vote_share  Capacity_min  Capacity_max  RUCC_2013
# 680          0.554567          0.86          0.86        7.0
# 183          0.490368          0.75          0.87        7.0
# 276          0.456274          0.84          0.92        2.0
# 684          0.565806          0.86          0.86        1.0
# 280          0.395213          0.49          0.73        7.0
# ..                ...           ...           ...        ...
# 111          0.570370          1.06          1.06        6.0
# 335          0.266949          1.10          1.10        2.0
# 395          0.721707          0.80          1.17        7.0
# 378          0.759031          1.21          2.14        7.0
# 654          0.329562          0.80          0.84        1.0
#
# [441 rows x 14 columns]

# %%
train_y
# Out:
#      cases_diff
# 680   52.574608
# 183   -7.709679
# 276   12.830837
# 684   13.450539
# 280   -0.508502
# ..          ...
# 111   -0.108277
# 335   -8.643114
# 395   11.359329
# 378   16.590814
# 654   30.998573
#
# [441 rows x 1 columns]

# %%
test_X
# Out:
#      incarc_rate  pct_white  Unemployment_rate_2019  Unemployment_rate_2020  \
# 656     0.003434   0.922306                1.360977                     4.8
# 61      0.007859   0.660698                1.945910                    11.3
# 655     0.059290   0.939558                1.410987                     3.7
# 205     0.004633   0.776987                1.526056                     7.7
# 536     0.045064   0.903759                1.740466                     6.8
# ..           ...        ...                     ...                     ...
# 71      0.142639   0.911369                1.686399                     7.7
# 190     0.006369   0.906011                1.308333                     4.9
# 164     0.022717   0.723460                1.410987                     4.6
# 194     0.024485   0.933521                1.667707                     6.7
# 62      0.015013   0.888069                1.360977                     7.7
#
#      PCTPOVALL_2019  Median_Household_Income_2019  Uninsured: %  \
# 656        2.066863                       71835.0      2.388763
# 61         2.681022                       68458.0      2.219203
# 655        2.646175                       54648.0      2.760010
# 205        3.273364                       37308.0      2.230014
# 536        2.701361                       58286.0      2.541602
# ..              ...                           ...           ...
# 71         2.839078                       52239.0      2.322388
# 190        2.674149                       53306.0      2.572612
# 164        2.332144                       72425.0      2.541602
# 194        2.694627                       48866.0      2.844909
# 62         2.533697                       76599.0      2.079442
#
#      Percent of adults with less than a high school diploma, 2015-19  \
# 656                                                9.4
# 61                                                20.7
# 655                                                9.8
# 205                                                8.1
# 536                                               17.6
# ..                                                 ...
# 71                                                 9.9
# 190                                                7.5
# 164                                                9.1
# 194                                                9.5
# 62                                                 8.7
#
#      Percent of adults with a high school diploma only, 2015-19  \
# 656                                               29.6
# 61                                                28.3
# 655                                               28.9
# 205                                               24.1
# 536                                               28.5
# ..                                                 ...
# 71                                                39.3
# 190                                               26.4
# 164                                               29.8
# 194                                               36.1
# 62                                                19.9
#
#      Percent of adults with a bachelor's degree or higher, 2015-19  \
# 656                                               24.5
# 61                                                18.8
# 655                                               20.9
# 205                                               34.1
# 536                                               17.2
# ..                                                 ...
# 71                                                18.5
# 190                                               27.8
# 164                                               25.4
# 194                                               19.8
# 62                                                35.4
#
#      trump_vote_share  Capacity_min  Capacity_max  RUCC_2013
# 656          0.473136          0.80          0.84        2.0
# 61           0.396742          0.78          1.10        2.0
# 655          0.656533          0.80          0.84        6.0
# 205          0.440468          0.64          0.69        3.0
# 536          0.618147          0.89          0.95        4.0
# ..                ...           ...           ...        ...
# 71           0.688208          1.05          1.17        4.0
# 190          0.514125          1.18          1.18        3.0
# 164          0.752740          0.75          0.87        3.0
# 194          0.782339          1.18          1.18        6.0
# 62           0.416002          0.78          1.10        2.0
#
# [148 rows x 14 columns]

# %%
pred_y.shape
# Out:
# (148,)

# %%
test_y.shape
# Out:
# (148, 1)

# %%
test_y = test_y['cases_diff'].tolist()

# %%
(
    ggplot(pd.DataFrame(dict(pred=pred_y,truth=test_y)),
          aes(x='pred',y="truth")) +
    geom_point(alpha=.75) +
    geom_abline(linetype="dashed",color="darkred",size=1) +
    theme_bw() +
    theme(figure_size=(10,7))
)
# Out:
# <ggplot: (8787299389904)>

# %%
rf_mod = search.best_estimator_

#Permute the features to determine importance. 
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=25)

# %%
#Permute the features to determine importance. 
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=25)

# %%
#Organize the output as a data frame. 

# Organize as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# Generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# But in order from most to least important
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)


vi_dat
# Out:
#                                              variable        vi       std  \
# 0   Percent of adults with a bachelor's degree or ...  0.391508  0.029170
# 1   Percent of adults with a high school diploma o...  0.189671  0.030961
# 2   Percent of adults with less than a high school...  0.188757  0.029330
# 3                                        Uninsured: %  0.108408  0.020015
# 4                                           pct_white  0.055098  0.016871
# 5                                           RUCC_2013  0.030849  0.010675
# 6                                        Capacity_min  0.026637  0.010690
# 7                                        Capacity_max  0.025757  0.008998
# 8                        Median_Household_Income_2019  0.025383  0.008939
# 9                              Unemployment_rate_2019  0.023754  0.009031
# 10                             Unemployment_rate_2020  0.016871  0.007710
# 11                                     PCTPOVALL_2019  0.014609  0.005641
# 12                                   trump_vote_share  0.001200  0.002462
# 13                                        incarc_rate  0.000594  0.001109
#
#          low      high
# 0   0.333169  0.449848
# 1   0.127748  0.251593
# 2   0.130097  0.247417
# 3   0.068378  0.148438
# 4   0.021356  0.088839
# 5   0.009499  0.052199
# 6   0.005257  0.048018
# 7   0.007760  0.043754
# 8   0.007506  0.043261
# 9   0.005692  0.041816
# 10  0.001451  0.032290
# 11  0.003328  0.025890
# 12 -0.003723  0.006124
# 13 -0.001624  0.002812

# %%
# Plot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Mean Squared Error",x="")
)
# Out:
# <ggplot: (8787194845088)>

# %%
# Target specific features
features = ["Percent of adults with a bachelor's degree or higher, 2015-19", 'Uninsured: %','pct_white']

# Calculate the partial dependency
fig, ax = plt.subplots(figsize=(15, 4))
display = plot_partial_dependence(
    rf_mod, train_X, features,n_cols=3,
    n_jobs=4, grid_resolution=30,ax=ax
)
# display.figure_.set_figwidth(15)
# display.figure_.set_figheight(4)

# %%
## ICE Plots

features = ['Uninsured: %']
fig, ax = plt.subplots(figsize=(15, 4))
display = PartialDependenceDisplay.from_estimator(
    rf_mod,
    train_X,
    features,
    kind="both", # "average" = just PDP, "individual" = just ICE
    subsample=50,
    n_jobs=3,
    grid_resolution=20,
    random_state=0,
    ice_lines_kw={"color": "tab:blue", "alpha": 0.5, "linewidth": 0.5},
    pd_line_kw={"color": "tab:orange", "linestyle": "--"},
    n_cols=len(features),
    ax = ax
)
display.figure_.subplots_adjust(hspace=0.3)
